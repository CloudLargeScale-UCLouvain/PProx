# %% [markdown]
# # Experimentation scripts for Pprox microbenchmark evaluation

# %% [markdown]
# ## Global parameters

# %%
shell_log=False
hostAddress="10-0-0-33.nip.io"
from tqdm.notebook import tqdm

# %% [markdown]
# ### Mongo db & collection initialization

# %%
from pymongo import MongoClient
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

client = MongoClient("manager-mongo-manager")

db = client["private-recsys"]
collection_experiment = db["experiments"]

# %% [markdown]
# ### Low level scripting functions

# %%
import subprocess
import shlex
import datetime
from dateutil.tz import tzlocal
import pandas as pd
import glob
import time
from time import sleep 
def run_command_async(command):
    if (isinstance(command, list) == False):
        commands = [command]
    else:
        commands=command
    processes = [None] * len(commands)
    for i in range(len(commands)):
        processes[i] = subprocess.Popen(shlex.split(commands[i]), stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    return processes

def wait_for_command_async(processes):
    while processes:
        for i, process in enumerate(processes):
            output = process.stdout.readline().decode()
            if output == '' and process.poll() is not None:
                processes.remove(process)
                break
            if output:
                now=datetime.datetime.now(tzlocal())
                strnow = now.strftime("%Y-%m-%d %H:%M:%S")
                print ("Log {0} - {1} : ".format(i,strnow) + output.strip())
    
    rc = process.poll()
    return rc    
def run_command(command, shell=False, log=True):
    print(command)
    if (isinstance(command, list) == False):
        commands = [command]
    else:
        commands=command
    processes = [None] * len(commands)
    for i in range(len(commands)):
        if log == True:
            print (commands[i])
        processes[i] = subprocess.Popen(shlex.split(commands[i]), stdout=subprocess.PIPE, stderr=subprocess.STDOUT, shell=shell)
    while processes:
        for i, process in enumerate(processes):
            output = process.stdout.readline().decode()
            if output == '' and process.poll() is not None:
                processes.remove(process)
                break
            if output and log:
                now=datetime.datetime.now(tzlocal())
                strnow = now.strftime("%Y-%m-%d %H:%M:%S")
                print ("Log {0} - {1} : ".format(i,strnow) + output.strip())
    
    rc = process.poll()
    return rc
import os

class cd:
    """Context manager for changing the current working directory"""
    def __init__(self, newPath):
        self.newPath = os.path.expanduser(newPath)

    def __enter__(self):
        self.savedPath = os.getcwd()
        os.chdir(self.newPath)

    def __exit__(self, etype, value, traceback):
        os.chdir(self.savedPath)
def get_strnow():
    now=datetime.datetime.now(tzlocal())
    return now.strftime("%Y%m%d%H%M%S")

# %% [markdown]
# ### Module scope functions

# %%
def wait_for_http_status(url, code, duration):
    import requests
    import time
    print
    req_code = None
    start_time = time.time()
    end_time= time.time()
    while req_code != code and (end_time - start_time) < duration :
        try:
            time.sleep(1)
            r = requests.head(url)
            req_code = r.status_code
            print("\rWaiting status {} for {} seconds            ".format(code, end_time - start_time), end="\r", flush=True)
            return 0
        except requests.ConnectionError:
            print("failed to connect")
            return 1
        end_time = time.time()    

def wait_for_job(name, duration):
    with cd(".."):
        command = "./wait_for_job.sh {} {}".format(name, duration)
        result = run_command(command, log = shell_log)
        return result
        
def install_recsys(params):
    
    run_command("helm init --client-only", log = shell_log)
    #launch commands manually
    #with cd("PrivateRecSys/charts/private-recsys"):
    #   run_command("helm repo add main https://kubernetes-charts.storage.googleapis.com/")
    #    run_command("helm repo add elastic https://helm.elastic.co")
    #    run_command("helm dep update") # can't work https://github.com/helm/helm/issues/2998 : it should be done on the node
        
    with cd("../../charts/private-recsys"):
        run_command("kubectl apply -f ..", log = shell_log)
        param_str = ""
        for k in params.keys():
            param_str += "--set {}={} ".format(str(k).replace("!","."), str(params[k]).replace("!","."))
        command = "helm install --name recsys --namespace default . {} --wait --timeout {} ".format(param_str, params["timeout"])
        result = run_command(command, log = shell_log)
        return result    
    
def uninstall_recsys():
    with cd("../../charts/private-recsys"):
        result = run_command("helm delete --purge recsys", log = shell_log)
        if result == 0:
            sleep(120)
    return result

def install_stub(params):
    
    run_command("helm init --client-only")
    #launch commands manually
    #with cd("PrivateRecSys/charts/private-recsys"):
    #   run_command("helm repo add main https://kubernetes-charts.storage.googleapis.com/")
    #    run_command("helm repo add elastic https://helm.elastic.co")
    #    run_command("helm dep update") # can't work https://github.com/helm/helm/issues/2998 : it should be done on the node
        
    with cd("../../charts/stub-recsys"):
        param_str = ""
        for k in params.keys():
            param_str += "--set {}={} ".format(str(k).replace("!","."), str(params[k]).replace("!","."))
        command = "helm install --name stub --namespace default . {} --wait --timeout {} ".format(param_str, params["timeout"])
        result = run_command(command, log = shell_log)
        return result    

def uninstall_stub():
    with cd("../../charts/stub-recsys"):
        result = run_command("helm delete --purge stub", log = shell_log)
        if result == 0:
            sleep(30)
    return result

def launch_injector(params):
    with cd("../../charts/injector"):
        param_str = ""
        for k in params.keys():
            param_str += "--set {}={} ".format(str(k).replace("!","."), str(params[k]).replace("!","."))
        command = "helm install --name injector --namespace default . {} --wait --timeout {}".format(param_str, params["timeout"])
        result = run_command(command, log = shell_log)
    
    if result == 0:
        #result = run_command("kubectl wait --namespace default --for=condition=complete --timeout={}s job/injector-injector".format(params["timeout"]+600), log = shell_log)
        result = wait_for_job("injector-injector", params["timeout"]+600)
    return result
    
def uninstall_injector():
    with cd("../../charts/injector"):
        result = run_command("helm delete --purge injector", log = shell_log)
        if result == 0:
            sleep(30)
    return result

# %% [markdown]
# ### Test scope functions

# %%
def is_harness_result_ok(collection):
    row = collection.find_one({"http_status":201})
    if row is not None:
        #print(row["content"]["result"])
        if len(row["content"]["result"]) > 0:
            return True
    else:
        print("Empty db")
    return False
def deploy_test(params):
    # uninstall previous launches
    print(uninstall_stub())
    print(uninstall_injector())
    print(uninstall_recsys())

    # init naming for experiment
    strnow = get_strnow()
    params_recsys = params["params_recsys"]
    params_injector = params["params_injector"]
    
    params["name"] = params["name"] + strnow
    params_injector["name"] = params_injector["name"] + strnow
    params_recsys["name"] = params_recsys["name"] + strnow
    
    # add labels with names
    params_injector["experiment"] = params["name"] 
    params_recsys["experiment"] = params["name"] 
    params_recsys["proxy-sgx!experiment"] = params["name"]
    params_recsys["harness!experiment"] = params["name"]
    
    mongo_id = collection_experiment.insert_one(params).inserted_id
    collection_experiment.update_one({'_id':mongo_id}, {"$set": params}, upsert=False)

    # init step recsys
    params_recsys["start_time"] = time.time()
    params["status"] = "recsys"
    collection_experiment.update_one({'_id':mongo_id}, {"$set": params}, upsert=False)
    
    cpt = 0
    err = None
    while (err is None or err != 0) and cpt < 5:
        
        if params["stub"] != "1":
            err=install_recsys(params_recsys)
        else:
            err=install_stub(params_recsys)
        print("err={}".format(err))
        if err != 0:
            if params["stub"] != "1":
                uninstall_recsys()
            else:
                uninstall_stub()
        cpt += 1

    params_recsys["end_time"] = time.time()
    params["status"] = "recsys"
    if err != 0:
        params["status"] = "recsys_error"

    collection_experiment.update_one({'_id':mongo_id}, {"$set": params}, upsert=False)
    return params["status"]    
def run_test(params):
    # uninstall previous launches
    print(uninstall_injector())

    # init naming for experiment
    strnow = get_strnow()
    params_recsys = params["params_recsys"]
    params_injector = params["params_injector"]
    
    params["name"] = params["name"] + strnow
    params_injector["name"] = params_injector["name"] + strnow
    params_recsys["name"] = params_recsys["name"] + strnow
    
    # add labels with names
    params_injector["experiment"] = params["name"] 
    params_recsys["experiment"] = params["name"] 
    params_recsys["proxy-sgx!experiment"] = params["name"]
    params_recsys["harness!experiment"] = params["name"]
    
    mongo_id = collection_experiment.insert_one(params).inserted_id
    collection_experiment.update_one({'_id':mongo_id}, {"$set": params}, upsert=False)
   
    params_injector["start_time"] = time.time()
    params["status"] = "injector"
    collection_experiment.update_one({'_id':mongo_id}, {"$set": params}, upsert=False)
    if params["stub"] != "1":
        time.sleep(120)
    cpt = 0

    err = launch_injector(params_injector)
    print("Injector deployment err : {}".format(err))
    #uninstall_injector()

    if err != 0:
        if err == 1:
            # failed injector, we assume it is harness
            params["status"] = "harness_error"
        return params["status"]
    
    params_injector["end_time"] = time.time()
    params["status"] = "injector"
    collection_experiment.update_one({'_id':mongo_id}, {"$set": params}, upsert=False)

    params_injector["error"] = err
    params_injector["end_time"] = time.time()
    #now=datetime.datetime.now(tzlocal())
    #strnow = now.strftime("%Y%m%d%H%M%S")



    coll_name = "private-recsys.{}.locust_request_result".format(params_injector["name"]) 
    coll = db[coll_name]
    params["status"] = "finished"
    
    #if params["stub"] != "1":
    #    if is_harness_result_ok(coll) == False:
    #        params["status"] = "harness_error"
    #print("{} - {}".format(coll_name, is_harness_result_ok(coll)))
        
    params["end_time"] = time.time()
    collection_experiment.update_one({'_id':mongo_id}, {"$set": params}, upsert=False)
    return params["status"]

# %% [markdown]
# ### Test functions

# %%
import itertools
import collections
def unpack_dict(target):
    ar = collections.OrderedDict()
    for k in target.keys():
        if isinstance(target[k], list):
            ar[k] = target[k]
    print(ar.keys())
    combinations = [dict(zip(ar.keys(), i)) for i in itertools.product(*ar.values())]
    result = []
    for c in combinations:
        print(c)
        d = target.copy()
        d.update(c)
        result.append(d)
    return result, ar

def rename_db(old, new):
    import pymongo
    from pymongo import MongoClient
    client = MongoClient("manager-mongo-manager")
    client.admin.command('copydb',
                         fromdb=old,
                         todb=new)
    client.drop_database(old)
    
def loop_run_test(params_packed):
    list_params_recsys, arrays_params_recsys = unpack_dict(params_packed["params_recsys"])
    list_params_injector, arrays_params_injector = unpack_dict(params_packed["params_injector"])

    strnow = get_strnow()
    print("db:" + "-".join(list(arrays_params_recsys))+"_"+"-".join(list(arrays_params_injector))+"_"+strnow)

    print(list_params_injector)
    first=True
    for params_recsys in list_params_recsys:
        params = params_packed.copy()
        params["params_recsys"] = params_recsys.copy()
        result = deploy_test(params.copy())
        
        if result != "recsys":
            break
        for params_injector in list_params_injector:
            for i in range(5):
                params = params_packed.copy()
                params["params_recsys"] = params_recsys.copy()
                params["params_injector"] = params_injector.copy()
                if first == True:
                    print("First launch")
                    
                    result = run_test(params.copy())
                    if result != "finished":
                        print("Launch {} in error, redeploying recsys.".format(i))
                        result = deploy_test(params.copy())
                        
                    else:
                        first=False
                        break

                else:
                    print("Not first, no init/train needed")
                    params["params_injector"]["harness"] = False

                    result = run_test(params.copy())
                    if result != "harness_error":
                        break
    #rename database 
    #rename_db("private-recsys", "-".join(list(arrays_params_recsys))+"_"+"-".join(list(arrays_params_injector))+"_"+strnow)

def fusion_experiments_db(name_from, name_to, drop = False):
    import pymongo
    from pymongo import MongoClient
    client = MongoClient("manager-mongo-manager")    
    if drop == True:
        client.drop_database(name_to)
    from pymongo import MongoClient
    client = MongoClient("manager-mongo-manager")
    database_names = client.list_database_names()
    for database_name in database_names:
        if name_from in database_name:
            print(database_name)
            elements = list(client[database_name]["experiments"].find())
            client[name_to]["experiments"].insert_many(elements) 
            for coll_name in client[database_name].list_collection_names(nameOnly=True):
                if coll_name != "experiments":
                    elements = list(client[database_name][coll_name].find())
                    client[name_to][coll_name].insert_many(elements)
    
def remove_working_db():
    from pymongo import MongoClient
    client = MongoClient("manager-mongo-manager")   
    client.drop_database("private-recsys")

# %% [markdown]
# ## Remove deployment

# %%
# reset 

print(uninstall_stub())
print(uninstall_injector())
print(uninstall_recsys())

# %% [markdown]
# # m0/XP1: Test stub

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in tqdm(["50","100","150","200","250","500"], "Input RPS"):
            for identifier in tqdm(range(6) ,"Run"):
                for proxy in ["localhost:32000/sgx-proxy"]:
                    name = "xp1_{}_{}_".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":1,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"1",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":1,
                        "targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        #"targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

fusion_experiments_db("private-recsys", "micro1", True)

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in tqdm(["375","500"], "Input RPS"):
            for identifier in tqdm(range(6) ,"Run"):
                for proxy in ["localhost:32000/sgx-proxy"]:
                    name = "xp1_{}_{}_".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":1,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"1",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":2,
                        "targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        #"targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

fusion_experiments_db("private-recsys", "micro1_2i", True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5935882aa742> in <module>
# ----> 1 remove_working_db()
#       2
#       3 for debug in ["0"]:
#       4     for encryption in ["1"]:
#       5         for client in tqdm(["750","1000"], "Input RPS"):
#
# NameError: name 'remove_working_db' is not defined

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in tqdm(["375","500"], "Input RPS"):
            for identifier in tqdm(range(6) ,"Run"):
                for proxy in ["localhost:32000/sgx-proxy"]:
                    name = "xp1_{}_{}_".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":1,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"1",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":2,
                        "targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        #"targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

fusion_experiments_db("private-recsys", "micro1_ext", True)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Input RPS', max=2.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='Run', max=6.0, style=ProgressStyle(description_width='ini…
# odict_keys(['proxy-sgx!responseTimeout'])
# {'proxy-sgx!responseTimeout': 999999}
# odict_keys(['clients', 'targetHost'])
# {'clients': '375', 'targetHost': 'http://stub-stub-recsys:8080'}
# db:proxy-sgx!responseTimeout_clients-targetHost_20200430133238
# [{'duration': 300, 'clients': '375', 'replicaCount': 2, 'targetHost': 'http://stub-stub-recsys:8080', 'concurrency': 10, 'timeout': 1200, 'asyncFluentd': 'false', 'enableEncryption': '1', 'randomShift': '1', 'name': 'xp1_375_0_', 'harness': 'false'}]
# helm delete --purge stub
# 1
# helm delete --purge injector
# 0
# helm delete --purge recsys
# 0
# helm init --client-only
# helm init --client-only
# Log 0 - 2020-04-30 13:35:11 : $HELM_HOME has been configured at /home/jovyan/.helm.
# Log 0 - 2020-04-30 13:35:11 : Not installing Tiller due to 'client-only' flag having been set
# helm install --name stub --namespace default . --set hostAddress=10-0-0-33.nip.io --set harness.replicaCount=1 --set proxy-sgx.replicaCount=1 --set proxy-sgx.proxyType1=1 --set proxy-sgx.proxyType2=2 --set proxy-sgx.targetPort=8080 --set proxy-sgx.enableEncryption=1 --set proxy-sgx.bufferShuffling=1 --set proxy-sgx.responseTimeout=999999 --set proxy-sgx.debug=0 --set proxy-sgx.image.repository=localhost:32000/sgx-proxy --set mongo.replicaSet.enabled=true --set name=xp1_375_0_20200430133510 --set timeout=450 --set mongo.clusterDomain=cluster.local --set experiment=xp1_375_0_20200430133510 --set proxy-sgx.experiment=xp1_375_0_20200430133510 --set harness.experiment=xp1_375_0_20200430133510 --set start_time=1588253711.0284326  --wait --timeout 450
# err=0
# First launch
# helm delete --purge injector
# 1
# helm install --name injector --namespace default . --set duration=300 --set clients=375 --set replicaCount=2 --set targetHost=http://stub-stub-recsys:8080 --set concurrency=10 --set timeout=1200 --set asyncFluentd=false --set enableEncryption=1 --set randomShift=1 --set name=xp1_375_0_20200430133526 --set harness=false --set experiment=xp1_375_0_20200430133526 --set start_time=1588253726.0578337  --wait --timeout 1200
# ./wait_for_job.sh injector-injector 1800
# Injector deployment err : 0
# odict_keys(['proxy-sgx!responseTimeout'])
# {'proxy-sgx!responseTimeout': 999999}
# odict_keys(['clients', 'targetHost'])
# {'clients': '375', 'targetHost': 'http://stub-stub-recsys:8080'}
# db:proxy-sgx!responseTimeout_clients-targetHost_20200430134459
# [{'duration': 300, 'clients': '375', 'replicaCount': 2, 'targetHost': 'http://stub-stub-recsys:8080', 'concurrency': 10, 'timeout': 1200, 'asyncFluentd': 'false', 'enableEncryption': '1', 'randomShift': '1', 'name': 'xp1_375_1_', 'harness': 'false'}]
# helm delete --purge stub
# 0
# helm delete --purge injector
# 0
# helm delete --purge recsys
# 1
# helm init --client-only
# helm init --client-only
# Log 0 - 2020-04-30 13:46:01 : $HELM_HOME has been configured at /home/jovyan/.helm.
# Log 0 - 2020-04-30 13:46:01 : Not installing Tiller due to 'client-only' flag having been set
# helm install --name stub --namespace default . --set hostAddress=10-0-0-33.nip.io --set harness.replicaCount=1 --set proxy-sgx.replicaCount=1 --set proxy-sgx.proxyType1=1 --set proxy-sgx.proxyType2=2 --set proxy-sgx.targetPort=8080 --set proxy-sgx.enableEncryption=1 --set proxy-sgx.bufferShuffling=1 --set proxy-sgx.responseTimeout=999999 --set proxy-sgx.debug=0 --set proxy-sgx.image.repository=localhost:32000/sgx-proxy --set mongo.replicaSet.enabled=true --set name=xp1_375_1_20200430134601 --set timeout=450 --set mongo.clusterDomain=cluster.local --set experiment=xp1_375_1_20200430134601 --set proxy-sgx.experiment=xp1_375_1_20200430134601 --set harness.experiment=xp1_375_1_20200430134601 --set start_time=1588254361.1629279  --wait --timeout 450
# err=0
# First launch
# helm delete --purge injector
# 1
# helm install --name injector --namespace default . --set duration=300 --set clients=375 --set replicaCount=2 --set targetHost=http://stub-stub-recsys:8080 --set concurrency=10 --set timeout=1200 --set asyncFluentd=false --set enableEncryption=1 --set randomShift=1 --set name=xp1_375_1_20200430134614 --set harness=false --set experiment=xp1_375_1_20200430134614 --set start_time=1588254374.2113361  --wait --timeout 1200
# ./wait_for_job.sh injector-injector 1800
# Injector deployment err : 0
# odict_keys(['proxy-sgx!responseTimeout'])
# {'proxy-sgx!responseTimeout': 999999}
# odict_keys(['clients', 'targetHost'])
# {'clients': '375', 'targetHost': 'http://stub-stub-recsys:8080'}
# db:proxy-sgx!responseTimeout_clients-targetHost_20200430135548
# [{'duration': 300, 'clients': '375', 'replicaCount': 2, 'targetHost': 'http://stub-stub-recsys:8080', 'concurrency': 10, 'timeout': 1200, 'asyncFluentd': 'false', 'enableEncryption': '1', 'randomShift': '1', 'name': 'xp1_375_2_', 'harness': 'false'}]
# helm delete --purge stub
# 0
# helm delete --purge injector
# 0
# helm delete --purge recsys
# 1
# helm init --client-only
# helm init --client-only
# Log 0 - 2020-04-30 13:56:50 : $HELM_HOME has been configured at /home/jovyan/.helm.
# Log 0 - 2020-04-30 13:56:50 : Not installing Tiller due to 'client-only' flag having been set
# helm install --name stub --namespace default . --set hostAddress=10-0-0-33.nip.io --set harness.replicaCount=1 --set proxy-sgx.replicaCount=1 --set proxy-sgx.proxyType1=1 --set proxy-sgx.proxyType2=2 --set proxy-sgx.targetPort=8080 --set proxy-sgx.enableEncryption=1 --set proxy-sgx.bufferShuffling=1 --set proxy-sgx.responseTimeout=999999 --set proxy-sgx.debug=0 --set proxy-sgx.image.repository=localhost:32000/sgx-proxy --set mongo.replicaSet.enabled=true --set name=xp1_375_2_20200430135650 --set timeout=450 --set mongo.clusterDomain=cluster.local --set experiment=xp1_375_2_20200430135650 --set proxy-sgx.experiment=xp1_375_2_20200430135650 --set harness.experiment=xp1_375_2_20200430135650 --set start_time=1588255010.4014704  --wait --timeout 450
# err=0
# First launch
# helm delete --purge injector
# 1
# helm install --name injector --namespace default . --set duration=300 --set clients=375 --set replicaCount=2 --set targetHost=http://stub-stub-recsys:8080 --set concurrency=10 --set timeout=1200 --set asyncFluentd=false --set enableEncryption=1 --set randomShift=1 --set name=xp1_375_2_20200430135705 --set harness=false --set experiment=xp1_375_2_20200430135705 --set start_time=1588255025.4101176  --wait --timeout 1200
# ./wait_for_job.sh injector-injector 1800
# Injector deployment err : 0
# odict_keys(['proxy-sgx!responseTimeout'])
# {'proxy-sgx!responseTimeout': 999999}
# odict_keys(['clients', 'targetHost'])
# {'clients': '375', 'targetHost': 'http://stub-stub-recsys:8080'}
# db:proxy-sgx!responseTimeout_clients-targetHost_20200430140637
# [{'duration': 300, 'clients': '375', 'replicaCount': 2, 'targetHost': 'http://stub-stub-recsys:8080', 'concurrency': 10, 'timeout': 1200, 'asyncFluentd': 'false', 'enableEncryption': '1', 'randomShift': '1', 'name': 'xp1_375_3_', 'harness': 'false'}]
# helm delete --purge stub
# 0
# helm delete --purge injector
# 0
# helm delete --purge recsys
# 1
# helm init --client-only
# helm init --client-only
# Log 0 - 2020-04-30 14:07:39 : $HELM_HOME has been configured at /home/jovyan/.helm.
# Log 0 - 2020-04-30 14:07:39 : Not installing Tiller due to 'client-only' flag having been set
# helm install --name stub --namespace default . --set hostAddress=10-0-0-33.nip.io --set harness.replicaCount=1 --set proxy-sgx.replicaCount=1 --set proxy-sgx.proxyType1=1 --set proxy-sgx.proxyType2=2 --set proxy-sgx.targetPort=8080 --set proxy-sgx.enableEncryption=1 --set proxy-sgx.bufferShuffling=1 --set proxy-sgx.responseTimeout=999999 --set proxy-sgx.debug=0 --set proxy-sgx.image.repository=localhost:32000/sgx-proxy --set mongo.replicaSet.enabled=true --set name=xp1_375_3_20200430140739 --set timeout=450 --set mongo.clusterDomain=cluster.local --set experiment=xp1_375_3_20200430140739 --set proxy-sgx.experiment=xp1_375_3_20200430140739 --set harness.experiment=xp1_375_3_20200430140739 --set start_time=1588255659.5504282  --wait --timeout 450
# err=0
# First launch
# helm delete --purge injector
# 1
# helm install --name injector --namespace default . --set duration=300 --set clients=375 --set replicaCount=2 --set targetHost=http://stub-stub-recsys:8080 --set concurrency=10 --set timeout=1200 --set asyncFluentd=false --set enableEncryption=1 --set randomShift=1 --set name=xp1_375_3_20200430140754 --set harness=false --set experiment=xp1_375_3_20200430140754 --set start_time=1588255674.5264778  --wait --timeout 1200
# ./wait_for_job.sh injector-injector 1800
# Injector deployment err : 0
# odict_keys(['proxy-sgx!responseTimeout'])
# {'proxy-sgx!responseTimeout': 999999}
# odict_keys(['clients', 'targetHost'])
# {'clients': '375', 'targetHost': 'http://stub-stub-recsys:8080'}
# db:proxy-sgx!responseTimeout_clients-targetHost_20200430141727
# [{'duration': 300, 'clients': '375', 'replicaCount': 2, 'targetHost': 'http://stub-stub-recsys:8080', 'concurrency': 10, 'timeout': 1200, 'asyncFluentd': 'false', 'enableEncryption': '1', 'randomShift': '1', 'name': 'xp1_375_4_', 'harness': 'false'}]
# helm delete --purge stub
# 0
# helm delete --purge injector
# 0
# helm delete --purge recsys
# 1
# helm init --client-only
# helm init --client-only
# Log 0 - 2020-04-30 14:18:29 : $HELM_HOME has been configured at /home/jovyan/.helm.
# Log 0 - 2020-04-30 14:18:29 : Not installing Tiller due to 'client-only' flag having been set
# helm install --name stub --namespace default . --set hostAddress=10-0-0-33.nip.io --set harness.replicaCount=1 --set proxy-sgx.replicaCount=1 --set proxy-sgx.proxyType1=1 --set proxy-sgx.proxyType2=2 --set proxy-sgx.targetPort=8080 --set proxy-sgx.enableEncryption=1 --set proxy-sgx.bufferShuffling=1 --set proxy-sgx.responseTimeout=999999 --set proxy-sgx.debug=0 --set proxy-sgx.image.repository=localhost:32000/sgx-proxy --set mongo.replicaSet.enabled=true --set name=xp1_375_4_20200430141829 --set timeout=450 --set mongo.clusterDomain=cluster.local --set experiment=xp1_375_4_20200430141829 --set proxy-sgx.experiment=xp1_375_4_20200430141829 --set harness.experiment=xp1_375_4_20200430141829 --set start_time=1588256309.0515628  --wait --timeout 450
# err=0
# First launch
# helm delete --purge injector
# 1
# helm install --name injector --namespace default . --set duration=300 --set clients=375 --set replicaCount=2 --set targetHost=http://stub-stub-recsys:8080 --set concurrency=10 --set timeout=1200 --set asyncFluentd=false --set enableEncryption=1 --set randomShift=1 --set name=xp1_375_4_20200430141838 --set harness=false --set experiment=xp1_375_4_20200430141838 --set start_time=1588256318.0841205  --wait --timeout 1200
# ./wait_for_job.sh injector-injector 1800
# Injector deployment err : 0
# odict_keys(['proxy-sgx!responseTimeout'])
# {'proxy-sgx!responseTimeout': 999999}
# odict_keys(['clients', 'targetHost'])
# {'clients': '375', 'targetHost': 'http://stub-stub-recsys:8080'}
# db:proxy-sgx!responseTimeout_clients-targetHost_20200430142809
# [{'duration': 300, 'clients': '375', 'replicaCount': 2, 'targetHost': 'http://stub-stub-recsys:8080', 'concurrency': 10, 'timeout': 1200, 'asyncFluentd': 'false', 'enableEncryption': '1', 'randomShift': '1', 'name': 'xp1_375_5_', 'harness': 'false'}]
# helm delete --purge stub
# 0
# helm delete --purge injector
# 0
# helm delete --purge recsys
# 1
# helm init --client-only
# helm init --client-only
# Log 0 - 2020-04-30 14:29:11 : $HELM_HOME has been configured at /home/jovyan/.helm.
# Log 0 - 2020-04-30 14:29:11 : Not installing Tiller due to 'client-only' flag having been set
# helm install --name stub --namespace default . --set hostAddress=10-0-0-33.nip.io --set harness.replicaCount=1 --set proxy-sgx.replicaCount=1 --set proxy-sgx.proxyType1=1 --set proxy-sgx.proxyType2=2 --set proxy-sgx.targetPort=8080 --set proxy-sgx.enableEncryption=1 --set proxy-sgx.bufferShuffling=1 --set proxy-sgx.responseTimeout=999999 --set proxy-sgx.debug=0 --set proxy-sgx.image.repository=localhost:32000/sgx-proxy --set mongo.replicaSet.enabled=true --set name=xp1_375_5_20200430142911 --set timeout=450 --set mongo.clusterDomain=cluster.local --set experiment=xp1_375_5_20200430142911 --set proxy-sgx.experiment=xp1_375_5_20200430142911 --set harness.experiment=xp1_375_5_20200430142911 --set start_time=1588256951.301656  --wait --timeout 450
# err=0
# First launch
# helm delete --purge injector
# 1
# helm install --name injector --namespace default . --set duration=300 --set clients=375 --set replicaCount=2 --set targetHost=http://stub-stub-recsys:8080 --set concurrency=10 --set timeout=1200 --set asyncFluentd=false --set enableEncryption=1 --set randomShift=1 --set name=xp1_375_5_20200430142922 --set harness=false --set experiment=xp1_375_5_20200430142922 --set start_time=1588256962.284234  --wait --timeout 1200
# ./wait_for_job.sh injector-injector 1800
# Injector deployment err : 0
# HBox(children=(FloatProgress(value=0.0, description='Run', max=6.0, style=ProgressStyle(description_width='ini…
# odict_keys(['proxy-sgx!responseTimeout'])
# {'proxy-sgx!responseTimeout': 999999}
# odict_keys(['clients', 'targetHost'])
# {'clients': '500', 'targetHost': 'http://stub-stub-recsys:8080'}
# db:proxy-sgx!responseTimeout_clients-targetHost_20200430143854
# [{'duration': 300, 'clients': '500', 'replicaCount': 2, 'targetHost': 'http://stub-stub-recsys:8080', 'concurrency': 10, 'timeout': 1200, 'asyncFluentd': 'false', 'enableEncryption': '1', 'randomShift': '1', 'name': 'xp1_500_0_', 'harness': 'false'}]
# helm delete --purge stub
# 0
# helm delete --purge injector
# 0
# helm delete --purge recsys
# 1
# helm init --client-only
# helm init --client-only
# Log 0 - 2020-04-30 14:39:56 : $HELM_HOME has been configured at /home/jovyan/.helm.
# Log 0 - 2020-04-30 14:39:56 : Not installing Tiller due to 'client-only' flag having been set
# helm install --name stub --namespace default . --set hostAddress=10-0-0-33.nip.io --set harness.replicaCount=1 --set proxy-sgx.replicaCount=1 --set proxy-sgx.proxyType1=1 --set proxy-sgx.proxyType2=2 --set proxy-sgx.targetPort=8080 --set proxy-sgx.enableEncryption=1 --set proxy-sgx.bufferShuffling=1 --set proxy-sgx.responseTimeout=999999 --set proxy-sgx.debug=0 --set proxy-sgx.image.repository=localhost:32000/sgx-proxy --set mongo.replicaSet.enabled=true --set name=xp1_500_0_20200430143956 --set timeout=450 --set mongo.clusterDomain=cluster.local --set experiment=xp1_500_0_20200430143956 --set proxy-sgx.experiment=xp1_500_0_20200430143956 --set harness.experiment=xp1_500_0_20200430143956 --set start_time=1588257596.200422  --wait --timeout 450
# err=0
# First launch
# helm delete --purge injector
# 1
# helm install --name injector --namespace default . --set duration=300 --set clients=500 --set replicaCount=2 --set targetHost=http://stub-stub-recsys:8080 --set concurrency=10 --set timeout=1200 --set asyncFluentd=false --set enableEncryption=1 --set randomShift=1 --set name=xp1_500_0_20200430144013 --set harness=false --set experiment=xp1_500_0_20200430144013 --set start_time=1588257613.1324344  --wait --timeout 1200
# ./wait_for_job.sh injector-injector 1800
# Injector deployment err : 0
# odict_keys(['proxy-sgx!responseTimeout'])
# {'proxy-sgx!responseTimeout': 999999}
# odict_keys(['clients', 'targetHost'])
# {'clients': '500', 'targetHost': 'http://stub-stub-recsys:8080'}
# db:proxy-sgx!responseTimeout_clients-targetHost_20200430144947
# [{'duration': 300, 'clients': '500', 'replicaCount': 2, 'targetHost': 'http://stub-stub-recsys:8080', 'concurrency': 10, 'timeout': 1200, 'asyncFluentd': 'false', 'enableEncryption': '1', 'randomShift': '1', 'name': 'xp1_500_1_', 'harness': 'false'}]
# helm delete --purge stub
# 0
# helm delete --purge injector
# 0
# helm delete --purge recsys
# 1
# helm init --client-only
# helm init --client-only
# Log 0 - 2020-04-30 14:50:49 : $HELM_HOME has been configured at /home/jovyan/.helm.
# Log 0 - 2020-04-30 14:50:49 : Not installing Tiller due to 'client-only' flag having been set
# helm install --name stub --namespace default . --set hostAddress=10-0-0-33.nip.io --set harness.replicaCount=1 --set proxy-sgx.replicaCount=1 --set proxy-sgx.proxyType1=1 --set proxy-sgx.proxyType2=2 --set proxy-sgx.targetPort=8080 --set proxy-sgx.enableEncryption=1 --set proxy-sgx.bufferShuffling=1 --set proxy-sgx.responseTimeout=999999 --set proxy-sgx.debug=0 --set proxy-sgx.image.repository=localhost:32000/sgx-proxy --set mongo.replicaSet.enabled=true --set name=xp1_500_1_20200430145049 --set timeout=450 --set mongo.clusterDomain=cluster.local --set experiment=xp1_500_1_20200430145049 --set proxy-sgx.experiment=xp1_500_1_20200430145049 --set harness.experiment=xp1_500_1_20200430145049 --set start_time=1588258249.3356063  --wait --timeout 450
# err=0
# First launch
# helm delete --purge injector
# 1
# helm install --name injector --namespace default . --set duration=300 --set clients=500 --set replicaCount=2 --set targetHost=http://stub-stub-recsys:8080 --set concurrency=10 --set timeout=1200 --set asyncFluentd=false --set enableEncryption=1 --set randomShift=1 --set name=xp1_500_1_20200430145056 --set harness=false --set experiment=xp1_500_1_20200430145056 --set start_time=1588258256.3885431  --wait --timeout 1200
# ./wait_for_job.sh injector-injector 1800
# Injector deployment err : 0
# odict_keys(['proxy-sgx!responseTimeout'])
# {'proxy-sgx!responseTimeout': 999999}
# odict_keys(['clients', 'targetHost'])
# {'clients': '500', 'targetHost': 'http://stub-stub-recsys:8080'}
# db:proxy-sgx!responseTimeout_clients-targetHost_20200430150030
# [{'duration': 300, 'clients': '500', 'replicaCount': 2, 'targetHost': 'http://stub-stub-recsys:8080', 'concurrency': 10, 'timeout': 1200, 'asyncFluentd': 'false', 'enableEncryption': '1', 'randomShift': '1', 'name': 'xp1_500_2_', 'harness': 'false'}]
# helm delete --purge stub
# 0
# helm delete --purge injector
# 0
# helm delete --purge recsys
# 1
# helm init --client-only
# helm init --client-only
# Log 0 - 2020-04-30 15:01:31 : $HELM_HOME has been configured at /home/jovyan/.helm.
# Log 0 - 2020-04-30 15:01:31 : Not installing Tiller due to 'client-only' flag having been set
# helm install --name stub --namespace default . --set hostAddress=10-0-0-33.nip.io --set harness.replicaCount=1 --set proxy-sgx.replicaCount=1 --set proxy-sgx.proxyType1=1 --set proxy-sgx.proxyType2=2 --set proxy-sgx.targetPort=8080 --set proxy-sgx.enableEncryption=1 --set proxy-sgx.bufferShuffling=1 --set proxy-sgx.responseTimeout=999999 --set proxy-sgx.debug=0 --set proxy-sgx.image.repository=localhost:32000/sgx-proxy --set mongo.replicaSet.enabled=true --set name=xp1_500_2_20200430150131 --set timeout=450 --set mongo.clusterDomain=cluster.local --set experiment=xp1_500_2_20200430150131 --set proxy-sgx.experiment=xp1_500_2_20200430150131 --set harness.experiment=xp1_500_2_20200430150131 --set start_time=1588258891.7886932  --wait --timeout 450
# err=0
# First launch
# helm delete --purge injector
# 1
# helm install --name injector --namespace default . --set duration=300 --set clients=500 --set replicaCount=2 --set targetHost=http://stub-stub-recsys:8080 --set concurrency=10 --set timeout=1200 --set asyncFluentd=false --set enableEncryption=1 --set randomShift=1 --set name=xp1_500_2_20200430150146 --set harness=false --set experiment=xp1_500_2_20200430150146 --set start_time=1588258906.839364  --wait --timeout 1200
# ./wait_for_job.sh injector-injector 1800
# Injector deployment err : 0
# odict_keys(['proxy-sgx!responseTimeout'])
# {'proxy-sgx!responseTimeout': 999999}
# odict_keys(['clients', 'targetHost'])
# {'clients': '500', 'targetHost': 'http://stub-stub-recsys:8080'}
# db:proxy-sgx!responseTimeout_clients-targetHost_20200430151120
# [{'duration': 300, 'clients': '500', 'replicaCount': 2, 'targetHost': 'http://stub-stub-recsys:8080', 'concurrency': 10, 'timeout': 1200, 'asyncFluentd': 'false', 'enableEncryption': '1', 'randomShift': '1', 'name': 'xp1_500_3_', 'harness': 'false'}]
# helm delete --purge stub
# 0
# helm delete --purge injector
# 0
# helm delete --purge recsys
# 1
# helm init --client-only
# helm init --client-only
# Log 0 - 2020-04-30 15:12:22 : $HELM_HOME has been configured at /home/jovyan/.helm.
# Log 0 - 2020-04-30 15:12:22 : Not installing Tiller due to 'client-only' flag having been set
# helm install --name stub --namespace default . --set hostAddress=10-0-0-33.nip.io --set harness.replicaCount=1 --set proxy-sgx.replicaCount=1 --set proxy-sgx.proxyType1=1 --set proxy-sgx.proxyType2=2 --set proxy-sgx.targetPort=8080 --set proxy-sgx.enableEncryption=1 --set proxy-sgx.bufferShuffling=1 --set proxy-sgx.responseTimeout=999999 --set proxy-sgx.debug=0 --set proxy-sgx.image.repository=localhost:32000/sgx-proxy --set mongo.replicaSet.enabled=true --set name=xp1_500_3_20200430151222 --set timeout=450 --set mongo.clusterDomain=cluster.local --set experiment=xp1_500_3_20200430151222 --set proxy-sgx.experiment=xp1_500_3_20200430151222 --set harness.experiment=xp1_500_3_20200430151222 --set start_time=1588259542.5647182  --wait --timeout 450
# err=0
# First launch
# helm delete --purge injector
# 1
# helm install --name injector --namespace default . --set duration=300 --set clients=500 --set replicaCount=2 --set targetHost=http://stub-stub-recsys:8080 --set concurrency=10 --set timeout=1200 --set asyncFluentd=false --set enableEncryption=1 --set randomShift=1 --set name=xp1_500_3_20200430151235 --set harness=false --set experiment=xp1_500_3_20200430151235 --set start_time=1588259555.6283605  --wait --timeout 1200
# ./wait_for_job.sh injector-injector 1800
# Injector deployment err : 0
# odict_keys(['proxy-sgx!responseTimeout'])
# {'proxy-sgx!responseTimeout': 999999}
# odict_keys(['clients', 'targetHost'])
# {'clients': '500', 'targetHost': 'http://stub-stub-recsys:8080'}
# db:proxy-sgx!responseTimeout_clients-targetHost_20200430152210
# [{'duration': 300, 'clients': '500', 'replicaCount': 2, 'targetHost': 'http://stub-stub-recsys:8080', 'concurrency': 10, 'timeout': 1200, 'asyncFluentd': 'false', 'enableEncryption': '1', 'randomShift': '1', 'name': 'xp1_500_4_', 'harness': 'false'}]
# helm delete --purge stub
# 0
# helm delete --purge injector
# 0
# helm delete --purge recsys
# 1
# helm init --client-only
# helm init --client-only
# Log 0 - 2020-04-30 15:23:12 : $HELM_HOME has been configured at /home/jovyan/.helm.
# Log 0 - 2020-04-30 15:23:12 : Not installing Tiller due to 'client-only' flag having been set
# helm install --name stub --namespace default . --set hostAddress=10-0-0-33.nip.io --set harness.replicaCount=1 --set proxy-sgx.replicaCount=1 --set proxy-sgx.proxyType1=1 --set proxy-sgx.proxyType2=2 --set proxy-sgx.targetPort=8080 --set proxy-sgx.enableEncryption=1 --set proxy-sgx.bufferShuffling=1 --set proxy-sgx.responseTimeout=999999 --set proxy-sgx.debug=0 --set proxy-sgx.image.repository=localhost:32000/sgx-proxy --set mongo.replicaSet.enabled=true --set name=xp1_500_4_20200430152312 --set timeout=450 --set mongo.clusterDomain=cluster.local --set experiment=xp1_500_4_20200430152312 --set proxy-sgx.experiment=xp1_500_4_20200430152312 --set harness.experiment=xp1_500_4_20200430152312 --set start_time=1588260192.3105235  --wait --timeout 450
# err=0
# First launch
# helm delete --purge injector
# 1
# helm install --name injector --namespace default . --set duration=300 --set clients=500 --set replicaCount=2 --set targetHost=http://stub-stub-recsys:8080 --set concurrency=10 --set timeout=1200 --set asyncFluentd=false --set enableEncryption=1 --set randomShift=1 --set name=xp1_500_4_20200430152327 --set harness=false --set experiment=xp1_500_4_20200430152327 --set start_time=1588260207.4044454  --wait --timeout 1200
# ./wait_for_job.sh injector-injector 1800
# Injector deployment err : 0
# odict_keys(['proxy-sgx!responseTimeout'])
# {'proxy-sgx!responseTimeout': 999999}
# odict_keys(['clients', 'targetHost'])
# {'clients': '500', 'targetHost': 'http://stub-stub-recsys:8080'}
# db:proxy-sgx!responseTimeout_clients-targetHost_20200430153301
# [{'duration': 300, 'clients': '500', 'replicaCount': 2, 'targetHost': 'http://stub-stub-recsys:8080', 'concurrency': 10, 'timeout': 1200, 'asyncFluentd': 'false', 'enableEncryption': '1', 'randomShift': '1', 'name': 'xp1_500_5_', 'harness': 'false'}]
# helm delete --purge stub
# 0
# helm delete --purge injector
# 0
# helm delete --purge recsys
# 1
# helm init --client-only
# helm init --client-only
# Log 0 - 2020-04-30 15:34:02 : $HELM_HOME has been configured at /home/jovyan/.helm.
# Log 0 - 2020-04-30 15:34:02 : Not installing Tiller due to 'client-only' flag having been set
# helm install --name stub --namespace default . --set hostAddress=10-0-0-33.nip.io --set harness.replicaCount=1 --set proxy-sgx.replicaCount=1 --set proxy-sgx.proxyType1=1 --set proxy-sgx.proxyType2=2 --set proxy-sgx.targetPort=8080 --set proxy-sgx.enableEncryption=1 --set proxy-sgx.bufferShuffling=1 --set proxy-sgx.responseTimeout=999999 --set proxy-sgx.debug=0 --set proxy-sgx.image.repository=localhost:32000/sgx-proxy --set mongo.replicaSet.enabled=true --set name=xp1_500_5_20200430153402 --set timeout=450 --set mongo.clusterDomain=cluster.local --set experiment=xp1_500_5_20200430153402 --set proxy-sgx.experiment=xp1_500_5_20200430153402 --set harness.experiment=xp1_500_5_20200430153402 --set start_time=1588260842.9098263  --wait --timeout 450
# err=0
# First launch
# helm delete --purge injector
# 1
# helm install --name injector --namespace default . --set duration=300 --set clients=500 --set replicaCount=2 --set targetHost=http://stub-stub-recsys:8080 --set concurrency=10 --set timeout=1200 --set asyncFluentd=false --set enableEncryption=1 --set randomShift=1 --set name=xp1_500_5_20200430153415 --set harness=false --set experiment=xp1_500_5_20200430153415 --set start_time=1588260855.9511065  --wait --timeout 1200
# ./wait_for_job.sh injector-injector 1800
# Injector deployment err : 0
#
#
# private-recsys

# %%
fusion_experiments_db("private-recsys", "micro1_ext", True)
# Out:
# private-recsys

# %% [markdown]
# # m1/XP2: no encryption no SGX

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["0"]:              
        for client in tqdm(["50","100","150","200","250"], "Input RPS"):
            for identifier in tqdm(range(6) ,"Run"):
                for proxy in ["localhost:32000/sgx-proxy-nosgx"]:
                    name = "xp2_{}_{}_".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":1,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"1",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":1,
                        #"targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        "targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

fusion_experiments_db("private-recsys", "micro2", True)

# %% [markdown]
# # m2/xp3 encryption, nosgx

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in tqdm(["50","100","150","200","250"], "Input RPS"):
            for identifier in tqdm(range(6) ,"Run"):
                for proxy in ["localhost:32000/sgx-proxy-nosgx"]:
                    name = "xp3_{}_{}_".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":1,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"1",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":1,
                        #"targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        "targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

fusion_experiments_db("private-recsys", "micro3", True)

# %% [markdown]
# # m3/XP4: encyption, SGX

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in ["50","100","150","200","250","300"]:
            for identifier in range(12):
                for proxy in ["localhost:32000/sgx-proxy"]:
                    name = "proxy{}_{}".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":1,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"1",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":1,
                        #"targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        "targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

fusion_experiments_db("private-recsys", "micro4-0704", True)

# %% [markdown]
# # m4/xp5 injector -> p1 -> p2 -> stub ENCRYPTION, SGX, no P2 items encryption

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in tqdm(["50","100","150","200","250"], "Input RPS"):
            for identifier in tqdm(range(6) ,"Run"):
                for proxy in ["localhost:32000/sgx-proxy"]:
                    name = "proxy{}_{}".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":1,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"1",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!enableItemsDecryption":0,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":1,
                        #"targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        "targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

fusion_experiments_db("private-recsys", "micro5", True)

# %% [markdown]
# # m5/xp6 : xp4 with buffer shuffling 5

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in tqdm(["50","100","150","200","250"], "Input RPS"):
            for identifier in tqdm(range(6), "Run"):
                for proxy in ["localhost:32000/sgx-proxy"]:
                    name = "xp6_{}_{}".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":1,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"5",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":1,
                        #"targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        "targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

fusion_experiments_db("private-recsys", "micro6", True)

# %% [markdown]
# # m6/xp7 : xp4 with buffer shuffling 10

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in tqdm(["50","100","150","200","250"], "Input RPS"):
            for identifier in tqdm(range(6), "Run"):
                for proxy in ["localhost:32000/sgx-proxy"]:
                    name = "xp7_{}_{}".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":1,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"10",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":1,
                        #"targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        "targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

fusion_experiments_db("private-recsys", "micro7", True)

# %% [markdown]
# # m7/xp8 - double

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in tqdm(["50","100","150","200","250","500"], "Input RPS"):
            for identifier in tqdm(range(6), "Run"):
                for proxy in ["localhost:32000/sgx-proxy"]:
                    name = "xp8_{}_{}".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":2,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"10",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":1,
                        #"targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        "targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

fusion_experiments_db("private-recsys", "micro8", True)

# %% [markdown]
# # m8/ micro9a

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in tqdm(["50","100","150","200","250","500"], "Input RPS"):
            for identifier in tqdm(range(6), "Run"):
                for proxy in ["localhost:32000/sgx-proxy"]:
                    name = "xp9a_{}_{}".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":3,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"10",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":1,
                        #"targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        "targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

fusion_experiments_db("private-recsys", "micro9a", True)

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in tqdm(["50","100","150","200","250","500"], "Input RPS"):
            for identifier in tqdm(range(6), "Run"):
                for proxy in ["localhost:32000/sgx-proxy"]:
                    name = "xp9a_{}_{}".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":3,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"10",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":1,
                        #"targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        "targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

fusion_experiments_db("private-recsys", "micro9a", True)

# %% [markdown]
# # m9 / micro9b

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in tqdm(["50","100","150","200","250","500","750"], "Input RPS"):
            for identifier in tqdm(range(6), "Run"):
                for proxy in ["localhost:32000/sgx-proxy"]:
                    name = "xp9b_{}_{}".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":4,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"10",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":1,
                        #"targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        "targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

fusion_experiments_db("private-recsys", "micro9b_new", True)

# %%
remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in tqdm(["500"], "Input RPS"):
            for identifier in tqdm(range(3), "Run"):
                for proxy in ["localhost:32000/sgx-proxy"]:
                    name = "xp9b_{}_{}".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":4,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"10",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":2,
                        #"targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        "targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

#fusion_experiments_db("private-recsys", "micro9b_new", False)

# %% [markdown]
# # debug

# %%
#remove_working_db()

for debug in ["0"]:
    for encryption in ["1"]:              
        for client in tqdm(["500"], "Input RPS"):
            for identifier in tqdm(range(1), "Run"):
                for proxy in ["localhost:32000/sgx-proxy"]:
                    name = "micro9b2i_{}_{}".format(client, identifier)
                    params_recsys = {
                        "hostAddress":hostAddress,
                        "harness!replicaCount":1,
                        "proxy-sgx!replicaCount":4,
                        "proxy-sgx!proxyType1":"1",
                        "proxy-sgx!proxyType2":"2",
                        "proxy-sgx!targetPort":"8080",            
                        "proxy-sgx!enableEncryption":encryption,
                        "proxy-sgx!bufferShuffling":"10",
                        "proxy-sgx!responseTimeout":[999999],         
                        "proxy-sgx!debug":debug,
                        "proxy-sgx!image!repository":proxy,
                        "mongo!replicaSet!enabled": "true",
                        "name":name,
                        "timeout":450,
                    #    "mongo!clusterDomain":"nuc.local"  # Louvain
                        "mongo!clusterDomain":"cluster.local" # Bordeaux
                    }
                    params_injector={
                        "duration":300,
                        "clients":[client],
                        "replicaCount":2,
                        #"targetHost":["http://stub-stub-recsys:8080"],   # stub      
                        "targetHost":["http://stub-proxy-sgx-1:8080"], # pprox
                        "concurrency":10,
                        "timeout":1200,
                        "asyncFluentd":"false",
                        "enableEncryption":encryption,
                        "randomShift":"1",                
                        "name":name,
                        "harness":"false" # false if stub
                    }
                    params = {
                        "start_time":time.time(),
                        "params_recsys":params_recsys,
                        "params_injector":params_injector,
                        "name:":name,
                        "error_module":"",
                        "error":0,
                        "status":"created",
                        "name":name,
                        "stub":"1"
                    }

                    loop_run_test(params)

# %%
fusion_experiments_db("private-recsys", "debug_micro9b", True)
